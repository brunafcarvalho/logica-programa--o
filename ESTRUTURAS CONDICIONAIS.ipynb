# %% [markdown]
# CONDICIONAIS

# %%
num1= 5
num2= 10

num1>num2
# Out:
# False

# %%
print("verdade")
# Out:
# verdade

# %%
num1=5
num2= 10
if num1>num2:
  print("verdade")

# %%
num1=6
num2-10
if num1<num2:
  print("verdade")
# Out:
# verdade

# %%
num1=6
num2-10
if num1>num2:
  print("verdade")

# %%
num1=5
num2=10
if num1<num2:
  print("parabeeeeens")
# Out:
# parabeeeeens

# %%
num1=5
num2-10
if num1>num2:
  print("okkkk")
elif num1==num2:
    print("igual")
else: num1<num2:
      print("isso ai")
# Out:
#   File "<ipython-input-13-6adfb3af12e2>", line 7
#     else: num1<num2:
#                    ^
# SyntaxError: invalid syntax

# %%
num1=5
num2=10
if num1>num2:
  print("okkkk")
elif num1==num2:
    print("igual")
else:
      print("isso ai")
# Out:
# isso ai

# %%
num1= 35
num2=13
if num1<num2:
  print("verdade")
elif num2<num1:
    print("falso")
else:
      print("igual")
# Out:
# falso

# %%
num1=1400
num2=1400
if num1<num2:
  print("ok ratinho")
elif num1>num2:
 print("ai ai ai")
else: print("igual")
# Out:
# igual

# %%
renda1= 1300
renda2= 1600
if renda1>renda2:
 print("maior")
elif(renda1<renda2):
 print("menor")
else:print("igual")
# Out:
# menor

# %%
salario1=1000
salario2=1000
if salario1>salario2:
  print("maior")
elif salario2>salario1:
  print("menor")
else:print("igual")
# Out:
# igual

# %%
vale= 750
vale2= 725
if vale>vale2:
  print("vale1 é maior")
elif vale2>vale:
  print("vale2 é maior")
else: print("nenhuma está correta")
# Out:
# vale1 é maior

# %% [markdown]
# condicional com operadores lógicos

# %%
num1= 10
num2= 2
num3= 13

if num1>num2 and num3>num1:
  print("correto)")
# Out:
# correto)

# %%
if num1<num2 and num3>num2:
  print("correto)")

# %%
if num1<num2 and num3>num2:
  print("correto)")
else: print("alguma ta errada")
# Out:
# alguma ta errada

# %% [markdown]
# * IF É PRA TESTAR UMA VERDADE
# * IF/ELSE PRA TESTA VERDADEIRO OU FALSO
# * ELIF PRA TESTAR VARIOS TESTES
